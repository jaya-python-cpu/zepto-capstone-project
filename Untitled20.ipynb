# %%
import os
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

sns.set_theme(style="whitegrid")

os.makedirs("charts", exist_ok=True)

# %%
df = sns.load_dataset("titanic")

print("Dataset loaded successfully.")
print("Shape:", df.shape)

# Required offline fallback
df.to_csv("titanic.csv", index=False)

print("\nSaved offline fallback:")
print("titanic.csv")
# Out:
# Dataset loaded successfully.
# Shape: (891, 15)
#
# Saved offline fallback:
# titanic.csv

# %%
print("=" * 70)
print("DATASET INFO")
print("=" * 70)

df.info()

print("\n" + "=" * 70)
print("DESCRIPTIVE STATISTICS")
print("=" * 70)

display(df.describe(include="all").T)

print("\n" + "=" * 70)
print("SHAPE")
print("=" * 70)

print(df.shape)
# Out:
# ...
# DATASET INFO
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
#
# ...
# DESCRIPTIVE STATISTICS
# ...

# %%
missing_count = df.isnull().sum()
missing_percent = (df.isnull().mean() * 100).round(2)

missing_report = pd.DataFrame({
    "missing_count": missing_count,
    "missing_percentage": missing_percent
})

missing_report = missing_report[
    missing_report["missing_count"] > 0
].sort_values("missing_percentage", ascending=False)

print("Missing-value report:")
display(missing_report)
# Out:
# Missing-value report:
#              missing_count  missing_percentage
# deck                   688               77.22
# age                    177               19.87
# embarked                 2                0.22
# embark_town              2                0.22

# %%
print("Missing-value handling decisions")
print("=" * 70)

for column in missing_report.index:
    pct = missing_report.loc[column, "missing_percentage"]

    if pct < 5:
        strategy = "Drop rows containing missing values in this column."
    elif pct <= 30:
        strategy = "Impute missing values."
    else:
        strategy = (
            "Missingness is above 30%; use a dedicated 'missing' category "
            "or drop the column after considering its usefulness."
        )

    print(f"{column}: {pct:.2f}% missing -> {strategy}")
# Out:
# Missing-value handling decisions
# ...
# deck: 77.22% missing -> Missingness is above 30%; use a dedicated 'missing' category or drop the column after considering its usefulness.
# age: 19.87% missing -> Impute missing values.
# embarked: 0.22% missing -> Drop rows containing missing values in this column.
# embark_town: 0.22% missing -> Drop rows containing missing values in this column.

# %%
clean_df = df.copy()
deck_missing_pct = clean_df["deck"].isnull().mean() * 100

print(f"deck missing percentage: {deck_missing_pct:.2f}%")
print("Decision: drop 'deck' because missingness is very high.")

clean_df = clean_df.drop(columns=["deck"])
# Numeric age -> median
age_missing_pct = df["age"].isnull().mean() * 100
print(f"\nage missing percentage: {age_missing_pct:.2f}%")
print("Decision: median imputation because missingness is between 5% and 30%.")

clean_df["age"] = clean_df["age"].fillna(clean_df["age"].median())


# Categorical columns
for col in ["embarked", "embark_town"]:
    pct = df[col].isnull().mean() * 100

    print(f"\n{col} missing percentage: {pct:.2f}%")
    print("Decision: mode imputation because missingness is between 5% and 30%.")

    clean_df[col] = clean_df[col].fillna(clean_df[col].mode()[0])


# Any remaining missing values?
print("\nRemaining missing values:")
print(clean_df.isnull().sum()[clean_df.isnull().sum() > 0])
# Out:
# deck missing percentage: 77.22%
# Decision: drop 'deck' because missingness is very high.
#
# age missing percentage: 19.87%
# Decision: median imputation because missingness is between 5% and 30%.
#
# embarked missing percentage: 0.22%
# Decision: mode imputation because missingness is between 5% and 30%.
#
# embark_town missing percentage: 0.22%
# Decision: mode imputation because missingness is between 5% and 30%.
#
# Remaining missing values:
# Series([], dtype: int64)

# %%
clean_df.to_csv("titanic.csv", index=False)

print("Cleaned dataset saved to titanic.csv")
print("Shape:", clean_df.shape)
# Out:
# Cleaned dataset saved to titanic.csv
# Shape: (891, 14)

# %%
print("Missing values after cleaning:")
display(
    clean_df.isnull().sum()
    .to_frame("missing_count")
    .query("missing_count > 0")
)

print("\nCleaned dataframe shape:", clean_df.shape)
# Out:
# Missing values after cleaning:
# Empty DataFrame
# Columns: [missing_count]
# Index: []
# Cleaned dataframe shape: (891, 14)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(clean_df["age"], kde=True, ax=axes[0], color="steelblue")
axes[0].set_title("Age Distribution")
axes[0].set_xlabel("Age")

sns.boxplot(x=clean_df["age"], ax=axes[1], color="skyblue")
axes[1].set_title("Age Box Plot")
axes[1].set_xlabel("Age")

plt.tight_layout()
plt.savefig("charts/age_distribution.png", dpi=150)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(clean_df["fare"], kde=True, ax=axes[0], color="darkorange")
axes[0].set_title("Fare Distribution")
axes[0].set_xlabel("Fare")

sns.boxplot(x=clean_df["fare"], ax=axes[1], color="orange")
axes[1].set_title("Fare Box Plot")
axes[1].set_xlabel("Fare")

plt.tight_layout()
plt.savefig("charts/fare_distribution.png", dpi=150)
plt.show()

# %%
def iqr_outlier_count(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    mask = (series < lower) | (series > upper)

    return {
        "Q1": q1,
        "Q3": q3,
        "IQR": iqr,
        "lower_bound": lower,
        "upper_bound": upper,
        "outlier_count": mask.sum()
    }


age_outliers = iqr_outlier_count(clean_df["age"])
fare_outliers = iqr_outlier_count(clean_df["fare"])

print("AGE OUTLIERS")
display(pd.DataFrame([age_outliers]))

print("\nFARE OUTLIERS")
display(pd.DataFrame([fare_outliers]))
# Out:
# AGE OUTLIERS
#      Q1    Q3   IQR  lower_bound  upper_bound  outlier_count
# 0  22.0  35.0  13.0          2.5         54.5             66
# FARE OUTLIERS
#        Q1    Q3      IQR  lower_bound  upper_bound  outlier_count
# 0  7.9104  31.0  23.0896      -26.724      65.6344            116

# %%
fare_mean = clean_df["fare"].mean()
fare_median = clean_df["fare"].median()
fare_mode = clean_df["fare"].mode().iloc[0]

print(f"Fare Mean   : {fare_mean:.4f}")
print(f"Fare Median : {fare_median:.4f}")
print(f"Fare Mode   : {fare_mode:.4f}")

if fare_mean > fare_median > fare_mode:
    conclusion = "Fare is right-skewed."
elif fare_mean < fare_median < fare_mode:
    conclusion = "Fare is left-skewed."
else:
    conclusion = "Fare does not follow a simple mean > median > mode or mean < median < mode ordering."

print("\nInterpretation:")
print(conclusion)

print(
    "\nThe mean is substantially above the median, indicating that "
    "higher fares pull the average upward. This is consistent with "
    "a positively/right-skewed fare distribution."
)
# Out:
# Fare Mean   : 32.2042
# Fare Median : 14.4542
# Fare Mode   : 8.0500
#
# Interpretation:
# Fare is right-skewed.
#
# The mean is substantially above the median, indicating that higher fares pull the average upward. This is consistent with a positively/right-skewed fare distribution.

# %%
sex_survival = (
    clean_df.groupby("sex")["survived"]
    .mean()
    .mul(100)
    .round(2)
)

print("Survival rate by sex (%):")
display(sex_survival)

# Boolean masking example
female_rate = clean_df.loc[
    clean_df["sex"] == "female",
    "survived"
].mean()

male_rate = clean_df.loc[
    clean_df["sex"] == "male",
    "survived"
].mean()

print(f"Female survival rate: {female_rate * 100:.2f}%")
print(f"Male survival rate:   {male_rate * 100:.2f}%")
# Out:
# Survival rate by sex (%):
# sex
# female    74.20
# male      18.89
# Name: survived, dtype: float64
# Female survival rate: 74.20%
# Male survival rate:   18.89%

# %%
pclass_survival = (
    clean_df.groupby("pclass")["survived"]
    .mean()
    .mul(100)
    .round(2)
)

print("Survival rate by passenger class (%):")
display(pclass_survival)

first_class = clean_df.loc[
    clean_df["pclass"] == 1,
    "survived"
].mean()

third_class = clean_df.loc[
    clean_df["pclass"] == 3,
    "survived"
].mean()

print(f"1st class survival rate: {first_class * 100:.2f}%")
print(f"3rd class survival rate: {third_class * 100:.2f}%")
# Out:
# Survival rate by passenger class (%):
# pclass
# 1    62.96
# 2    47.28
# 3    24.24
# Name: survived, dtype: float64
# 1st class survival rate: 62.96%
# 3rd class survival rate: 24.24%

# %%
results = []

for sex in ["female", "male"]:
    for pclass in [1, 2, 3]:

        mask = (
            (clean_df["sex"] == sex)
            & (clean_df["pclass"] == pclass)
        )

        group = clean_df.loc[mask]

        results.append({
            "sex": sex,
            "pclass": pclass,
            "passengers": len(group),
            "survivors": group["survived"].sum(),
            "survival_rate": group["survived"].mean() * 100
        })

sex_pclass_survival = pd.DataFrame(results)

sex_pclass_survival["survival_rate"] = (
    sex_pclass_survival["survival_rate"].round(2)
)

print("Survival rate by sex and passenger class:")
display(sex_pclass_survival)
# Out:
# Survival rate by sex and passenger class:
#       sex  pclass  passengers  survivors  survival_rate
# 0  female       1          94         91          96.81
# 1  female       2          76         70          92.11
# 2  female       3         144         72          50.00
# 3    male       1         122         45          36.89
# 4    male       2         108         17          15.74
# 5    male       3         347         47          13.54

# %%
# Example using OR condition
young_or_female = clean_df.loc[
    (clean_df["age"] < 18) | (clean_df["sex"] == "female")
]

print(
    "Survival rate among passengers who were either under 18 "
    "OR female:",
    round(young_or_female["survived"].mean() * 100, 2),
    "%"
)
# Out:
# Survival rate among passengers who were either under 18 OR female: 68.82 %

# %%
correlation_columns = [
    "survived",
    "pclass",
    "age",
    "sibsp",
    "parch",
    "fare"
]

corr = clean_df[correlation_columns].corr()

print("Correlation matrix:")
display(corr.round(3))
# Out:
# Correlation matrix:
#           survived  pclass    age  sibsp  parch   fare
# survived     1.000  -0.338 -0.065 -0.035  0.082  0.257
# pclass      -0.338   1.000 -0.340  0.083  0.018 -0.549
# age         -0.065  -0.340  1.000 -0.233 -0.172  0.097
# sibsp       -0.035   0.083 -0.233  1.000  0.415  0.160
# parch        0.082   0.018 -0.172  0.415  1.000  0.216
# fare         0.257  -0.549  0.097  0.160  0.216  1.000

# %%
plt.figure(figsize=(9, 7))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    square=True,
    linewidths=0.5
)

plt.title("Titanic Numeric Feature Correlation Matrix")
plt.tight_layout()

plt.savefig("charts/correlation_heatmap.png", dpi=150)
plt.show()

# %%
pairs = []

for i in range(len(correlation_columns)):
    for j in range(i + 1, len(correlation_columns)):

        col1 = correlation_columns[i]
        col2 = correlation_columns[j]

        value = corr.loc[col1, col2]

        pairs.append({
            "feature_1": col1,
            "feature_2": col2,
            "correlation": value,
            "absolute_correlation": abs(value)
        })

strongest_pairs = (
    pd.DataFrame(pairs)
    .sort_values("absolute_correlation", ascending=False)
    .head(2)
)

print("Two strongest absolute off-diagonal correlations:")
display(strongest_pairs)
# Out:
# Two strongest absolute off-diagonal correlations:
#    feature_1 feature_2  correlation  absolute_correlation
# 8     pclass      fare    -0.549500              0.549500
# 12     sibsp     parch     0.414838              0.414838

# %%
for _, row in strongest_pairs.iterrows():

    direction = (
        "positive"
        if row["correlation"] > 0
        else "negative"
    )

    print(
        f"{row['feature_1']} and {row['feature_2']} have a "
        f"{direction} correlation of {row['correlation']:.3f}. "
        f"This is one of the two strongest absolute correlations "
        f"in the six-variable matrix."
    )
# Out:
# pclass and fare have a negative correlation of -0.549. This is one of the two strongest absolute correlations in the six-variable matrix.
# sibsp and parch have a positive correlation of 0.415. This is one of the two strongest absolute correlations in the six-variable matrix.

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=clean_df,
    x="sex",
    y="survived",
    errorbar=None,
    palette="Set2"
)

plt.title("Survival Rate by Sex")
plt.ylabel("Survival Rate")
plt.xlabel("Sex")
plt.ylim(0, 1)

plt.tight_layout()
plt.savefig("charts/survival_by_sex.png", dpi=150)
plt.show()

print("""
Interpretation:
The chart shows a clear difference in survival rates between female
and male passengers. Female passengers had a considerably higher
observed survival rate than male passengers in this dataset.
This indicates that sex was strongly associated with survival.
""")
# Out:
# Interpretation:
# The chart shows a clear difference in survival rates between female
# and male passengers. Female passengers had a considerably higher
# observed survival rate than male passengers in this dataset.
# This indicates that sex was strongly associated with survival.

# %%
plt.figure(figsize=(9, 6))

sns.barplot(
    data=clean_df,
    x="pclass",
    y="survived",
    hue="sex",
    errorbar=None
)

plt.title("Survival Rate by Passenger Class and Sex")
plt.ylabel("Survival Rate")
plt.xlabel("Passenger Class")
plt.ylim(0, 1)

plt.tight_layout()
plt.savefig("charts/survival_class_sex.png", dpi=150)
plt.show()

print("""
Interpretation:
Passenger class provides an additional separation in survival rates,
with higher-class passengers generally showing higher survival.
The sex difference remains visible within passenger classes, showing
that class and sex together provide a more detailed survival story.
""")
# Out:
# Interpretation:
# Passenger class provides an additional separation in survival rates,
# with higher-class passengers generally showing higher survival.
# The sex difference remains visible within passenger classes, showing
# that class and sex together provide a more detailed survival story.

# %%
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=clean_df,
    x="survived",
    y="age",
    palette="Set3"
)

plt.title("Age Distribution by Survival")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Age")

plt.tight_layout()
plt.savefig("charts/age_survival_boxplot.png", dpi=150)
plt.show()

print("""
Interpretation:
The box plot compares the age distributions of survivors and
non-survivors. The distributions overlap substantially, indicating
that age alone does not completely separate the two groups.
However, the presence of younger passengers among survivors provides
additional context for the survival pattern.
""")
# Out:
# Interpretation:
# The box plot compares the age distributions of survivors and
# non-survivors. The distributions overlap substantially, indicating
# that age alone does not completely separate the two groups.
# However, the presence of younger passengers among survivors provides
# additional context for the survival pattern.

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=clean_df,
    x="pclass",
    y="fare",
    hue="survived"
)

plt.title("Fare Distribution by Class and Survival")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")

plt.tight_layout()
plt.savefig("charts/fare_class_survival.png", dpi=150)
plt.show()

print("""
Interpretation:
Fare differs substantially across passenger classes, with higher
fares concentrated among higher-class passengers. Within classes,
survival groups can also show different fare distributions.
This supports the idea that fare and class jointly provide useful
information about passenger outcomes.
""")
# Out:
# Interpretation:
# Fare differs substantially across passenger classes, with higher
# fares concentrated among higher-class passengers. Within classes,
# survival groups can also show different fare distributions.
# This supports the idea that fare and class jointly provide useful
# information about passenger outcomes.

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=clean_df,
    x="age",
    y="fare",
    hue="survived",
    style="sex",
    alpha=0.65
)

plt.title("Age vs Fare by Survival and Sex")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.tight_layout()
plt.savefig("charts/age_fare_survival.png", dpi=150)
plt.show()

print("""
Interpretation:
The scatter plot combines age, fare, sex and survival in one view.
Higher fares are concentrated among certain passenger groups, while
survival outcomes vary across the feature space. The chart therefore
shows why multiple variables are useful for modeling survival instead
of relying on a single predictor.
""")
# Out:
# Interpretation:
# The scatter plot combines age, fare, sex and survival in one view.
# Higher fares are concentrated among certain passenger groups, while
# survival outcomes vary across the feature space. The chart therefore
# shows why multiple variables are useful for modeling survival instead
# of relying on a single predictor.

# %%
scaler_eda = StandardScaler()

standardized = scaler_eda.fit_transform(
    clean_df[["age", "fare"]]
)

standardized_df = pd.DataFrame(
    standardized,
    columns=["age_standardized", "fare_standardized"],
    index=clean_df.index
)

print("BEFORE STANDARDIZATION")
print(
    clean_df[["age", "fare"]]
    .agg(["mean", "std"])
)

print("\nAFTER STANDARDIZATION")
print(
    standardized_df
    .agg(["mean", "std"])
)
# Out:
# BEFORE STANDARDIZATION
#             age       fare
# mean  29.361582  32.204208
# std   13.019697  49.693429
#
# AFTER STANDARDIZATION
#       age_standardized  fare_standardized
# mean      2.272780e-16       3.987333e-18
# std       1.000562e+00       1.000562e+00

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 9))

sns.histplot(clean_df["age"], kde=True, ax=axes[0, 0])
axes[0, 0].set_title("Age Before Standardization")

sns.histplot(
    standardized_df["age_standardized"],
    kde=True,
    ax=axes[0, 1],
    color="green"
)
axes[0, 1].set_title("Age After Standardization")

sns.histplot(clean_df["fare"], kde=True, ax=axes[1, 0])
axes[1, 0].set_title("Fare Before Standardization")

sns.histplot(
    standardized_df["fare_standardized"],
    kde=True,
    ax=axes[1, 1],
    color="purple"
)
axes[1, 1].set_title("Fare After Standardization")

plt.tight_layout()
plt.savefig("charts/standardization_comparison.png", dpi=150)
plt.show()

# %%
print("=" * 70)
print("FINAL CLEAN DATASET")
print("=" * 70)

print("Shape:", clean_df.shape)

print("\nRemaining missing values:")
print(clean_df.isnull().sum()[clean_df.isnull().sum() > 0])

print("\nColumns:")
print(clean_df.columns.tolist())

print("\nSaved file:")
print("titanic.csv")
# Out:
# ...
# FINAL CLEAN DATASET
# ...
# Shape: (891, 14)
#
# Remaining missing values:
# Series([], dtype: int64)
#
# Columns:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive', 'alone']
#
# Saved file:
# titanic.csv

# %%
import os
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    StratifiedKFold
)

from sklearn.compose import ColumnTransformer

from sklearn.pipeline import Pipeline

from sklearn.impute import SimpleImputer

from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler
)

from sklearn.linear_model import LogisticRegression, LinearRegression

from sklearn.tree import (
    DecisionTreeClassifier,
    plot_tree
)

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score,
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

from sklearn.base import clone

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

import joblib

sns.set_theme(style="whitegrid")

os.makedirs("charts", exist_ok=True)

# %%
df = pd.read_csv("titanic.csv")

print("Loaded titanic.csv")
print("Shape:", df.shape)

display(df.head())
# Out:
# Loaded titanic.csv
# Shape: (891, 14)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
target = "survived"

# Avoid columns that directly/redundantly encode target information
# or are not needed for this modeling task.
drop_columns = [
    "survived",
    "alive",
    "embark_town"
]

X = df.drop(columns=drop_columns)
y = df[target]

print("Feature columns:")
print(X.columns.tolist())

print("\nTarget distribution:")
print(y.value_counts())

print("\nTarget distribution (%):")
print((y.value_counts(normalize=True) * 100).round(2))
# Out:
# Feature columns:
# ['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'alone']
#
# Target distribution:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# Target distribution (%):
# survived
# 0    61.62
# 1    38.38
# Name: proportion, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training shape:", X_train.shape)
print("Testing shape :", X_test.shape)

print("\nTraining class balance:")
print(y_train.value_counts(normalize=True).round(4))

print("\nTesting class balance:")
print(y_test.value_counts(normalize=True).round(4))
# Out:
# Training shape: (712, 11)
# Testing shape : (179, 11)
#
# Training class balance:
# survived
# 0    0.6166
# 1    0.3834
# Name: proportion, dtype: float64
#
# Testing class balance:
# survived
# 0    0.6145
# 1    0.3855
# Name: proportion, dtype: float64

# %%
categorical_features = [
    "sex",
    "embarked"
]

numeric_features = [
    col for col in X.columns
    if col not in categorical_features
]

print("Categorical features:")
print(categorical_features)

print("\nNumeric features:")
print(numeric_features)
# Out:
# Categorical features:
# ['sex', 'embarked']
#
# Numeric features:
# ['pclass', 'age', 'sibsp', 'parch', 'fare', 'class', 'who', 'adult_male', 'alone']

# %%
numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(
        handle_unknown="ignore",
        sparse_output=False
    ))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_pipeline, numeric_features),
        ("categorical", categorical_pipeline, categorical_features)
    ],
    remainder="drop"
)

print("Preprocessing pipeline created.")
# Out:
# Preprocessing pipeline created.

# %%
logistic_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", LogisticRegression(
        max_iter=2000,
        random_state=42
    ))
])

tree_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", DecisionTreeClassifier(
        random_state=42,
        max_depth=5
    ))
])

forest_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(
        n_estimators=300,
        random_state=42,
        n_jobs=-1,
        oob_score=True
    ))
])

# %%
models = {
    "Logistic Regression": logistic_pipeline,
    "Decision Tree": tree_pipeline,
    "Random Forest": forest_pipeline
}

for name, model in models.items():

    print(f"Training {name}...")

    model.fit(X_train, y_train)

    print(f"{name} completed.")

print("All three models trained on the identical train/test split.")
# Out:
# Training Logistic Regression...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5667/2000910487.py in <cell line: 0>()
#       9     print(f"Training {name}...")
#      10
# ---> 11     model.fit(X_train, y_train)
#      12
#      13     print(f"{name} completed.")
#
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.13/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     652
#     653         routed_params = self._check_method_params(method="fit", props=params)
# --> 654         Xt = self._fit(X, y, routed_params, raw_params=params)
# ...

# %%
def evaluate_classifier(name, model, X_test, y_test):

    predictions = model.predict(X_test)
    probabilities = model.predict_proba(X_test)[:, 1]

    cm = confusion_matrix(y_test, predictions)

    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions, zero_division=0)
    recall = recall_score(y_test, predictions, zero_division=0)
    f1 = f1_score(y_test, predictions, zero_division=0)
    auc = roc_auc_score(y_test, probabilities)

    return {
        "Model": name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "AUC": auc,
        "Confusion Matrix": cm,
        "y_pred": predictions,
        "y_prob": probabilities
    }


evaluation_results = {}

for name, model in models.items():

    evaluation_results[name] = evaluate_classifier(
        name,
        model,
        X_test,
        y_test
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5667/1287635558.py in <cell line: 0>()
#      29 for name, model in models.items():
#      30
# ---> 31     evaluation_results[name] = evaluate_classifier(
#      32         name,
#      33         model,
#
# /tmp/ipykernel_5667/1287635558.py in evaluate_classifier(name, model, X_test, y_test)
#       1 def evaluate_classifier(name, model, X_test, y_test):
#       2
# ----> 3     predictions = model.predict(X_test)
#       4     probabilities = model.predict_proba(X_test)[:, 1]
#       5
#
# /usr/local/lib/python3.13/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     785             if not _routing_enabled():
#     786                 for _, name, transform in self._iter(with_final=False):
# --> 787                     Xt = transform.transform(Xt)
# ...

# %%
for name, result in evaluation_results.items():

    print("=" * 70)
    print(name)
    print("=" * 70)

    print("Confusion Matrix:")
    print(result["Confusion Matrix"])

    print(f"Accuracy : {result['Accuracy']:.4f}")
    print(f"Precision: {result['Precision']:.4f}")
    print(f"Recall   : {result['Recall']:.4f}")
    print(f"F1 Score : {result['F1']:.4f}")
    print(f"AUC      : {result['AUC']:.4f}")

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for ax, (name, result) in zip(axes, evaluation_results.items()):

    disp = ConfusionMatrixDisplay(
        confusion_matrix=result["Confusion Matrix"],
        display_labels=["Not Survived", "Survived"]
    )

    disp.plot(
        ax=ax,
        cmap="Blues",
        colorbar=False
    )

    ax.set_title(name)

plt.tight_layout()
plt.savefig("charts/confusion_matrices.png", dpi=150)
plt.show()

# %%
plt.figure(figsize=(10, 7))

for name, result in evaluation_results.items():

    fpr, tpr, _ = roc_curve(
        y_test,
        result["y_prob"]
    )

    plt.plot(
        fpr,
        tpr,
        linewidth=2,
        label=f"{name} (AUC = {result['AUC']:.3f})"
    )

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    color="gray",
    label="Random classifier"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend()

plt.tight_layout()
plt.savefig("charts/roc_curves.png", dpi=150)
plt.show()

# %%
classification_table = pd.DataFrame([
    {
        "Model": name,
        "Accuracy": result["Accuracy"],
        "Precision": result["Precision"],
        "Recall": result["Recall"],
        "F1": result["F1"],
        "AUC": result["AUC"]
    }
    for name, result in evaluation_results.items()
])

classification_table = classification_table.set_index("Model")

display(
    classification_table.style
    .format("{:.4f}")
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5667/1572149071.py in <cell line: 0>()
#      11 ])
#      12
# ---> 13 classification_table = classification_table.set_index("Model")
#      14
#      15 display(
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Model'] are in the columns"

# %%
# Get the fitted preprocessing transformer
tree_preprocessor = tree_pipeline.named_steps["preprocessor"]

# Get feature names after one-hot encoding
tree_feature_names = tree_preprocessor.get_feature_names_out()

tree_model = tree_pipeline.named_steps["classifier"]

plt.figure(figsize=(24, 12))

plot_tree(
    tree_model,
    feature_names=tree_feature_names,
    class_names=["Not Survived", "Survived"],
    filled=True,
    rounded=True,
    fontsize=8
)

plt.title("Decision Tree Visualization")
plt.tight_layout()

plt.savefig(
    "charts/decision_tree.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5667/3853684322.py in <cell line: 0>()
#       3
#       4 # Get feature names after one-hot encoding
# ----> 5 tree_feature_names = tree_preprocessor.get_feature_names_out()
#       6
#       7 tree_model = tree_pipeline.named_steps["classifier"]
#
# /usr/local/lib/python3.13/dist-packages/sklearn/compose/_column_transformer.py in get_feature_names_out(self, input_features)
#     638         # List of tuples (name, feature_names_out)
#     639         transformer_with_feature_names_out = []
# --> 640         for name, trans, *_ in self._iter(
#     641             fitted=True,
#     642             column_as_labels=False,
#
# /usr/local/lib/python3.13/dist-packages/sklearn/compose/_column_transformer.py in _iter(self, fitted, column_as_labels, skip_drop, skip_empty_columns)
#     467         """
# ...

# %%
class_balance = pd.DataFrame({
    "count": y.value_counts(),
    "percentage": y.value_counts(normalize=True) * 100
})

class_balance.index.name = "survived"

display(class_balance.round(2))
# Out:
#           count  percentage
# survived
# 0           549       61.62
# 1           342       38.38

# %%
baseline_model = clone(logistic_pipeline)

baseline_model.fit(X_train, y_train)

baseline_pred = baseline_model.predict(X_test)

baseline_metrics = {
    "Strategy": "Baseline",
    "Precision": precision_score(
        y_test,
        baseline_pred,
        zero_division=0
    ),
    "Recall": recall_score(
        y_test,
        baseline_pred,
        zero_division=0
    ),
    "F1": f1_score(
        y_test,
        baseline_pred,
        zero_division=0
    )
}

baseline_metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5667/4290785128.py in <cell line: 0>()
#       1 baseline_model = clone(logistic_pipeline)
#       2
# ----> 3 baseline_model.fit(X_train, y_train)
#       4
#       5 baseline_pred = baseline_model.predict(X_test)
#
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.13/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     652
#     653         routed_params = self._check_method_params(method="fit", props=params)
# --> 654         Xt = self._fit(X, y, routed_params, raw_params=params)
# ...

# %%
balanced_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", LogisticRegression(
        max_iter=2000,
        class_weight="balanced",
        random_state=42
    ))
])

balanced_pipeline.fit(X_train, y_train)

balanced_pred = balanced_pipeline.predict(X_test)

balanced_metrics = {
    "Strategy": "class_weight='balanced'",
    "Precision": precision_score(
        y_test,
        balanced_pred,
        zero_division=0
    ),
    "Recall": recall_score(
        y_test,
        balanced_pred,
        zero_division=0
    ),
    "F1": f1_score(
        y_test,
        balanced_pred,
        zero_division=0
    )
}

balanced_metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5667/2707538396.py in <cell line: 0>()
#       8 ])
#       9
# ---> 10 balanced_pipeline.fit(X_train, y_train)
#      11
#      12 balanced_pred = balanced_pipeline.predict(X_test)
#
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.13/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     652
#     653         routed_params = self._check_method_params(method="fit", props=params)
# --> 654         Xt = self._fit(X, y, routed_params, raw_params=params)
#     655         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
# ...

# %%
smote_pipeline = ImbPipeline([
    ("preprocessor", preprocessor),
    ("smote", SMOTE(
        random_state=42
    )),
    ("classifier", LogisticRegression(
        max_iter=2000,
        random_state=42
    ))
])

smote_pipeline.fit(X_train, y_train)

smote_pred = smote_pipeline.predict(X_test)

smote_metrics = {
    "Strategy": "SMOTE",
    "Precision": precision_score(
        y_test,
        smote_pred,
        zero_division=0
    ),
    "Recall": recall_score(
        y_test,
        smote_pred,
        zero_division=0
    ),
    "F1": f1_score(
        y_test,
        smote_pred,
        zero_division=0
    )
}

smote_metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5667/3550065354.py in <cell line: 0>()
#      10 ])
#      11
# ---> 12 smote_pipeline.fit(X_train, y_train)
#      13
#      14 smote_pred = smote_pipeline.predict(X_test)
#
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.13/dist-packages/imblearn/pipeline.py in fit(self, X, y, **params)
#     512
#     513         routed_params = self._check_method_params(method="fit", props=params)
# --> 514         Xt, yt = self._fit(X, y, routed_params, raw_params=params)
#     515         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
# ...

# %%
imbalance_table = pd.DataFrame([
    baseline_metrics,
    balanced_metrics,
    smote_metrics
])

display(
    imbalance_table.style.format({
        "Precision": "{:.4f}",
        "Recall": "{:.4f}",
        "F1": "{:.4f}"
    })
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5667/329158465.py in <cell line: 0>()
#       1 imbalance_table = pd.DataFrame([
# ----> 2     baseline_metrics,
#       3     balanced_metrics,
#       4     smote_metrics
#       5 ])
#
# NameError: name 'baseline_metrics' is not defined

# %%
regression_df = df.copy()

# Target
regression_target = regression_df["fare"]

# Remove target and high-leakage / unsuitable fields.
# 'alive' directly represents survival outcome and is not appropriate
# as an explanatory variable for this fare task.
regression_features = regression_df.drop(
    columns=[
        "fare",
        "alive"
    ]
)

print("Regression features:")
print(regression_features.columns.tolist())
# Out:
# Regression features:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alone']

# %%
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(
    regression_features,
    regression_target,
    test_size=0.20,
    random_state=42
)

print("Regression training shape:", X_reg_train.shape)
print("Regression testing shape :", X_reg_test.shape)
# Out:
# Regression training shape: (712, 12)
# Regression testing shape : (179, 12)

# %%
reg_categorical = X_reg_train.select_dtypes(
    include=["object", "category", "bool"]
).columns.tolist()

reg_numeric = [
    col for col in X_reg_train.columns
    if col not in reg_categorical
]

print("Regression categorical:")
print(reg_categorical)

print("\nRegression numeric:")
print(reg_numeric)
# Out:
# Regression categorical:
# ['sex', 'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alone']
#
# Regression numeric:
# ['survived', 'pclass', 'age', 'sibsp', 'parch']

# %%
reg_numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

reg_categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(
        handle_unknown="ignore",
        sparse_output=False
    ))
])

reg_preprocessor = ColumnTransformer([
    ("numeric", reg_numeric_pipeline, reg_numeric),
    ("categorical", reg_categorical_pipeline, reg_categorical)
])

regression_pipeline = Pipeline([
    ("preprocessor", reg_preprocessor),
    ("regressor", LinearRegression())
])

regression_pipeline.fit(
    X_reg_train,
    y_reg_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['survived', 'pclass', 'age',
#                                                    'sibsp', 'parch']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %%
y_reg_pred = regression_pipeline.predict(X_reg_test)

mae = mean_absolute_error(
    y_reg_test,
    y_reg_pred
)

rmse = np.sqrt(
    mean_squared_error(
        y_reg_test,
        y_reg_pred
    )
)

r2 = r2_score(
    y_reg_test,
    y_reg_pred
)

# Number of observations and predictors after transformation
X_reg_test_transformed = (
    regression_pipeline
    .named_steps["preprocessor"]
    .transform(X_reg_test)
)

n = X_reg_test_transformed.shape[0]
p = X_reg_test_transformed.shape[1]

if n - p - 1 > 0:
    adjusted_r2 = (
        1
        - ((1 - r2) * (n - 1) / (n - p - 1))
    )
else:
    adjusted_r2 = np.nan

regression_metrics = {
    "MAE": mae,
    "RMSE": rmse,
    "R2": r2,
    "Adjusted R2": adjusted_r2
}

print(f"MAE        : {mae:.4f}")
print(f"RMSE       : {rmse:.4f}")
print(f"R²         : {r2:.4f}")
print(f"Adjusted R²: {adjusted_r2:.4f}")
# Out:
# MAE        : 19.0615
# RMSE       : 31.1286
# R²         : 0.3738
# Adjusted R²: 0.2809

# %%
residuals = y_reg_test - y_reg_pred

plt.figure(figsize=(10, 6))

sns.scatterplot(
    x=y_reg_pred,
    y=residuals,
    alpha=0.65
)

plt.axhline(
    0,
    color="red",
    linestyle="--"
)

plt.xlabel("Predicted Fare")
plt.ylabel("Residual")
plt.title("Fare Regression Residual Plot")

plt.tight_layout()
plt.savefig("charts/fare_residual_plot.png", dpi=150)
plt.show()

# %%
# Simple visual diagnostic based on residual spread.

abs_residuals = np.abs(residuals)

correlation_abs_residuals = np.corrcoef(
    y_reg_pred,
    abs_residuals
)[0, 1]

print(
    "Correlation between predicted fare and absolute residuals:",
    round(correlation_abs_residuals, 4)
)

if abs(correlation_abs_residuals) > 0.3:
    hetero_conclusion = (
        "The residual plot suggests possible heteroscedasticity because "
        "the residual spread changes with the predicted fare."
    )
else:
    hetero_conclusion = (
        "The residual plot does not show strong evidence of "
        "heteroscedasticity based on this visual/numerical diagnostic."
    )

print("\nConclusion:")
print(hetero_conclusion)
# Out:
# Correlation between predicted fare and absolute residuals: 0.6683
#
# Conclusion:
# The residual plot suggests possible heteroscedasticity because the residual spread changes with the predicted fare.

# %%
final_classification_table = classification_table.copy()

print("CLASSIFICATION METRICS")
display(final_classification_table.round(4))

print("\nREGRESSION METRICS")
regression_table = pd.DataFrame({
    "Regression Metric": [
        "MAE",
        "RMSE",
        "R²",
        "Adjusted R²"
    ],
    "Value": [
        mae,
        rmse,
        r2,
        adjusted_r2
    ]
})

display(regression_table.round(4))
# Out:
# CLASSIFICATION METRICS
# Empty DataFrame
# Columns: []
# Index: []
# REGRESSION METRICS
#   Regression Metric    Value
# 0               MAE  19.0615
# 1              RMSE  31.1286
# 2                R²   0.3738
# 3       Adjusted R²   0.2809

# %%
pipeline_path = "titanic_best_pipeline.joblib"

joblib.dump(
    full_pipeline,
    pipeline_path
)

print(f"Complete pipeline saved to: {pipeline_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5667/1022457614.py in <cell line: 0>()
#       2
#       3 joblib.dump(
# ----> 4     full_pipeline,
#       5     pipeline_path
#       6 )
#
# NameError: name 'full_pipeline' is not defined

# %%
best_rf_pipeline = grid_search.best_estimator_

best_rf_classifier = (
    best_rf_pipeline
    .named_steps["classifier"]
)

print("OOB score:")
print(f"{best_rf_classifier.oob_score_:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5667/1384592866.py in <cell line: 0>()
# ----> 1 best_rf_pipeline = grid_search.best_estimator_
#       2
#       3 best_rf_classifier = (
#       4     best_rf_pipeline
#       5     .named_steps["classifier"]
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
print("=" * 80)
print("MODULE 2 FINAL VERIFICATION")
print("=" * 80)

checks = {
    "titanic.csv exists": os.path.exists("titanic.csv"),
    "pipeline exists": os.path.exists("titanic_best_pipeline.joblib"),
    "charts directory exists": os.path.exists("charts"),
    "3 classifiers evaluated": len(evaluation_results) == 3,
    "GridSearch completed": hasattr(grid_search, "best_params_"),
    "OOB score available": hasattr(best_rf_classifier, "oob_score_"),
    "Regression metrics calculated": all(
        key in regression_metrics
        for key in ["MAE", "RMSE", "R2", "Adjusted R2"]
    )
}

for check, passed in checks.items():
    print(f"{'PASS' if passed else 'FAIL'} - {check}")

print("\nModule 2 implementation complete.")
# Out:
# ...
# MODULE 2 FINAL VERIFICATION
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5667/1807029335.py in <cell line: 0>()
#       9     "3 classifiers evaluated": len(evaluation_results) == 3,
#      10     "GridSearch completed": hasattr(grid_search, "best_params_"),
# ---> 11     "OOB score available": hasattr(best_rf_classifier, "oob_score_"),
#      12     "Regression metrics calculated": all(
#      13         key in regression_metrics
#
# NameError: name 'best_rf_classifier' is not defined
